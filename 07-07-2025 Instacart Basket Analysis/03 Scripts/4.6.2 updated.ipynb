# %%
#Import libraries
import pandas as pd
import numpy as np
import os

# %%
# Import databases
path = r'C:\Users\amuly\07-07-2025 Instacart Basket Analysis\02 Data'

# %%
# Import dataframe

orders_products_combined_checked = pd.read_pickle(os.path.join(path,'Prepared Data' , 'orders_products_combined_checked.pkl'))

df_prods = pd.read_csv(os.path.join(path, 'Prepared Data' , 'products_checked.csv'), index_col = 0)

# %%
# Check the shape of the imported dataframe

orders_products_combined_checked.shape
# Out:
# (2078068, 11)

# %%
orders_products_combined_checked.head()
# Out:
#    Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0           0   2539329        1             1                   2
# 1           0   2539329        1             1                   2
# 2           0   2539329        1             1                   2
# 3           0   2539329        1             1                   2
# 4           0   2539329        1             1                   2
#
#    order_hour_of_day  days_since_prior_order  product_id  add_to_cart_order  \
# 0                  8                     NaN         196                  1
# 1                  8                     NaN       14084                  2
# 2                  8                     NaN       12427                  3
# 3                  8                     NaN       26088                  4
# 4                  8                     NaN       26405                  5
#
#    reordered _merge
# 0          0   both
# 1          0   both
# 2          0   both
# 3          0   both
# 4          0   both

# %%
df_prods.shape
# Out:
# (49672, 5)

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
# test merge without overwriting with merge flag 'match'

pd.merge(orders_products_combined_checked , df_prods , on = ['product_id'] , how = 'inner', indicator = 'match' )
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 0   2539329        1             1                   2
# 2                 0   2539329        1             1                   2
# 3                 0   2539329        1             1                   2
# 4                 0   2539329        1             1                   2
# ...             ...       ...      ...           ...                 ...
# 2076091     3421069   3154581   206209             1                   3
# 2076092     3421069   3154581   206209             1                   3
# 2076093     3421069   3154581   206209             1                   3
# 2076094     3421069   3154581   206209             1                   3
# 2076095     3421069   3154581   206209             1                   3
#
#          order_hour_of_day  days_since_prior_order  product_id  \
# 0                        8                     NaN         196
# 1                        8                     NaN       14084
# 2                        8                     NaN       12427
# 3                        8                     NaN       26088
# 4                        8                     NaN       26405
# ...                    ...                     ...         ...
# 2076091                 11                     NaN       20073
# 2076092                 11                     NaN       13176
# 2076093                 11                     NaN       20842
# 2076094                 11                     NaN       23594
# 2076095                 11                     NaN       25837
#
#          add_to_cart_order  reordered _merge  \
# 0                        1          0   both
# 1                        2          0   both
# 2                        3          0   both
# 3                        4          0   both
# 4                        5          0   both
# ...                    ...        ...    ...
# 2076091                  9          0   both
# 2076092                 10          0   both
# 2076093                 11          0   both
# 2076094                 12          0   both
# 2076095                 13          0   both
#
#                                      product_name  aisle_id  department_id  \
# 0                                            Soda        77              7
# 1         Organic Unsweetened Vanilla Almond Milk        91             16
# 2                             Original Beef Jerky        23             19
# 3                      Aged White Cheddar Popcorn        23             19
# 4                XL Pick-A-Size Paper Towel Rolls        54             17
# ...                                           ...       ...            ...
# 2076091                                Jazz Apple        24              4
# 2076092                    Bag of Organic Bananas        24              4
# 2076093                     Total 0% Greek Yogurt       120             16
# 2076094                              Medium Salsa        51             13
# 2076095  Mini Babybel Light Semisoft Edam Cheeses        21             16
#
#          prices match
# 0           9.0  both
# 1          12.5  both
# 2           4.4  both
# 3           4.7  both
# 4           1.0  both
# ...         ...   ...
# 2076091     6.4  both
# 2076092    10.3  both
# 2076093    13.6  both
# 2076094     3.7  both
# 2076095     3.8  both
#
# [2076096 rows x 16 columns]

# %%
# actual merge of 'orders_products_combined' and '_df_pords'

ords_prods_merge = orders_products_combined_checked.merge(df_prods , on = ['product_id'] , indicator = 'match' )

# %%
# drop the flag column '_merge' from the previous merge

ords_prods_merge.drop('_merge', axis = 1 )
# Out:
#          Unnamed: 0  order_id  user_id  order_number  orders_day_of_week  \
# 0                 0   2539329        1             1                   2
# 1                 0   2539329        1             1                   2
# 2                 0   2539329        1             1                   2
# 3                 0   2539329        1             1                   2
# 4                 0   2539329        1             1                   2
# ...             ...       ...      ...           ...                 ...
# 2076091     3421069   3154581   206209             1                   3
# 2076092     3421069   3154581   206209             1                   3
# 2076093     3421069   3154581   206209             1                   3
# 2076094     3421069   3154581   206209             1                   3
# 2076095     3421069   3154581   206209             1                   3
#
#          order_hour_of_day  days_since_prior_order  product_id  \
# 0                        8                     NaN         196
# 1                        8                     NaN       14084
# 2                        8                     NaN       12427
# 3                        8                     NaN       26088
# 4                        8                     NaN       26405
# ...                    ...                     ...         ...
# 2076091                 11                     NaN       20073
# 2076092                 11                     NaN       13176
# 2076093                 11                     NaN       20842
# 2076094                 11                     NaN       23594
# 2076095                 11                     NaN       25837
#
#          add_to_cart_order  reordered  \
# 0                        1          0
# 1                        2          0
# 2                        3          0
# 3                        4          0
# 4                        5          0
# ...                    ...        ...
# 2076091                  9          0
# 2076092                 10          0
# 2076093                 11          0
# 2076094                 12          0
# 2076095                 13          0
#
#                                      product_name  aisle_id  department_id  \
# 0                                            Soda        77              7
# 1         Organic Unsweetened Vanilla Almond Milk        91             16
# 2                             Original Beef Jerky        23             19
# 3                      Aged White Cheddar Popcorn        23             19
# 4                XL Pick-A-Size Paper Towel Rolls        54             17
# ...                                           ...       ...            ...
# 2076091                                Jazz Apple        24              4
# 2076092                    Bag of Organic Bananas        24              4
# 2076093                     Total 0% Greek Yogurt       120             16
# 2076094                              Medium Salsa        51             13
# 2076095  Mini Babybel Light Semisoft Edam Cheeses        21             16
#
#          prices match
# 0           9.0  both
# 1          12.5  both
# 2           4.4  both
# 3           4.7  both
# 4           1.0  both
# ...         ...   ...
# 2076091     6.4  both
# 2076092    10.3  both
# 2076093    13.6  both
# 2076094     3.7  both
# 2076095     3.8  both
#
# [2076096 rows x 15 columns]

# %%
#exporting dataframe as pickle
ords_prods_merge.to_pickle(os.path.join(path, 'Prepared data' ,'ords_prods_merge_checked.pkl'))
